# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

    
class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        
    def search(self, target):            # Our target param rep data we're looking for
        current = self.head              # We initialize "current" at the head of our list.
        found = False                    # Create boolean variable "found" that represents the search state.
        while current:                   # Loop as long as current is not None (see NoneType)
            if current.data == target:   #If the node referenced by "current" has the data we're looking for
                found = True             # Set found to True and..
                break                    # exit the loopl
            current = current.next       #  Otherwise, current will point to the next node in our list.
        return found                     #  Our method returns whatever valoue "found" has
    
    # 1. Create method for LinkedList class that returns
    # index of target value if it exists in the list.
    # method should be called "index"
    
    def index(self, target):
        current = self.head
        index = -1
        while current:
            index+=1
            if current.data == target:
                index+=1
                break
            current = current.next
        return index
    
    # 2. Create a method for LinkedList class that returns
    # value at a given index if the index exists.
    # the method should be called data_at.
    
    def data_at(self, target):
        current = self.head
        current_index = 0
        
        while current:
            if index == current_index:
                return current.data
            current = current.next
            current_index += 1
        
        raise Exception("index out of bounds")
        
    def prepend(self, data):
        # create node w/ incoming data
        node = Node(data)
        # store a temp reference to current "head":
        current_head = self.head
        # set self.head to point to node
        self.head = node
        # link "node" at self.head to "current_head" thus linking to rest of list
        self.head.next = current_head
        
#    def append(self, data):
#        if not self.head:
#            self.head = Node(data)
#        else:
#            # loop until we find the end of our list:
#            current = self.head
#            while current.next:
#                current = current.next
#            current.next = Node(data)
 
    def get_tail(self):
        if self.tail:
            return self.tail
        if not self.head:
            return None
        current = self.head
        while current.next:
            current = current.next
        self.tail = current
        return self.tail
    
    def append(self, data):
        current = self.get_tail()
        if not current:
            self.head = Node(data)
            self.tail = self.head
        else:
            current.next = Node(data)
            self.tail.next = Node(data)
            
    def insert(self, index_after, data):
        tail = self.get_tail()
        if not tail:
            raise Exception("reference to head not set.")
        current = self.head
        current_index = 0
        found = False
        while current:
            if current_index == index_after:
                new_node = Node(data)
                current.next = new_node
                found = True
                if new_node.next == None:
                    self.tail = new_node
                break
            current = current.next
            current_index +=1
        if not Found:
            raise Exception("index out of bounds.")
        
    def remove(self, target):
        tail = self.get_tail()
        if not self.head:
            raise Exception("Reference to head not set.")
        current = self.head
        if current.data == target:
            self.head = self.head.next
        while current.next:
            previous = curent
            current = current.next
            if current.data == target:
                previous.next = current.next
                found = True
                if previous.next == None:
                    self.tail = previous
        if not found:
            raise Exception("Target not in list.")
            
        def __str__(self):
            current = self.head
            out = ""
            while current:
                out += "%d, " % current.data
                current = current.next
            return "[%s]" % out

# %%
my_list = LinkedList()

for number in range(10):
    my_list.append(number)
    
print(my_list)

# %%
a = [1,2,3,4]
print(a[::-1])
# Out:
# [4, 3, 2, 1]

# %%
class DNode:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.prev = None

class DLList:
    def __init__(self, data):
        self.head = None
        
    def append(self, data): #append data to end of list
        if not self.head:
            new_node = DNode(data)
            self.head = new_node
        else:
            current = self.head
            while current:
                current = current.next
            new_node = DNode(data)
            current.next = new_node
            new_node.prev = current
        
    def remove_last(self,data):
        tail = self.tail()
        current = self.head
        if not self.head:
            return False
    
        if current.data == data:
            self.head = self.head.next
            self.head.prev = None
            return True
        while current.next:
            previous = current
            current = current.next
        if current.data == data:
            previous.next = current.next
            found = True
        if previous.next == None:
            self.tail = previous
        if not found:
            return current data
# Out:
#   File "/var/folders/f3/2gw4f4sx2fxcc4l5x7ypbnhr0000gn/T/ipykernel_13030/1265742685.py", line 42
#     return current data
#                    ^
# SyntaxError: invalid syntax
